# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import style
style.use("ggplot")
from sklearn.cluster import KMeans
from datetime import datetime

# %%
costumers = pd.read_csv('olist_customers_dataset.csv')
itens = pd.read_csv('olist_order_items_dataset.csv')
payments = pd.read_csv('olist_order_payments_dataset.csv')
reviews = pd.read_csv('olist_order_reviews_dataset.csv')
orders = pd.read_csv('olist_orders_dataset.csv')
products = pd.read_csv('olist_products_dataset.csv')

# %%
costumers_orders = pd.merge(costumers, orders, on='customer_id')

# %%
cols = ['customer_id','customer_city','customer_state','order_id']
costumers_orders = costumers_orders[cols]

# %%
costumers_itens = pd.merge(costumers_orders, itens, on='order_id')

# %%
costumers_itens = costumers_itens.drop(columns='order_item_id')

# %%
costumers_products = pd.merge(costumers_itens, products, on='product_id')

# %%
costumers_products = costumers_products.drop(columns=['product_name_lenght','product_description_lenght','product_photos_qty'])

# %%
costumers_products_payments = pd.merge(costumers_products, payments, on='order_id')

# %%
costumers_products_payments = costumers_products_payments.drop(columns=['payment_sequential','payment_value' ])

# %%
costumers_products_payments_review = pd.merge(costumers_products_payments, reviews, on='order_id')

# %%
costumers_dataset = costumers_products_payments_review.drop(columns=['review_comment_title','review_comment_message', 'review_creation_date', 'review_answer_timestamp','review_id','seller_id','product_id','order_id','customer_id'])

# %%
costumers_dataset
# Out:
#                 customer_city customer_state  shipping_limit_date   price  \
# 0                      franca             SP  2017-05-22 15:22:12  124.99
# 1                    santarem             PA  2017-11-23 00:47:18  112.99
# 2                    santarem             PA  2017-11-23 00:47:18  112.99
# 3             nova santa rita             RS  2017-05-22 22:22:56  124.99
# 4                        mage             RJ  2018-02-18 21:29:19  106.99
# 5                    angelina             SC  2017-04-05 15:25:11  126.99
# 6                    contagem             MG  2017-05-23 03:45:27  124.99
# 7               varzea grande             MT  2017-03-29 23:04:36  126.99
# 8              belo horizonte             MG  2018-03-29 07:55:24  116.99
# 9       santa rita do sapucai             MG  2018-02-13 03:47:31  106.99
# 10      santa rita do sapucai             MG  2018-02-13 03:47:31  106.99
# 11                     gaspar             SC  2017-05-23 11:45:13  124.99
# 12                     gaspar             SC  2017-05-23 11:45:13  124.99
# 13                     gaspar             SC  2017-05-23 11:45:13  124.99
# 14                     gaspar             SC  2017-05-23 11:45:13  124.99
# 15                     gaspar             SC  2017-05-23 11:45:13  124.99
# 16                     gaspar             SC  2017-05-23 11:45:13  124.99
# 17                    pelotas             RS  2018-02-13 19:54:04  106.99
# 18                 petropolis             RJ  2017-10-25 11:49:47  116.99
# 19                montalvania             MG  2017-02-18 16:19:02  119.99
# 20                montalvania             MG  2017-02-18 16:19:02  119.99
# 21                    colider             MT  2018-02-21 18:15:27  116.99
# 22                  sao paulo             SP  2017-07-11 03:45:30  124.99
# 23             belo horizonte             MG  2017-10-25 10:49:15  112.99
# 24                   salvador             BA  2018-04-10 15:51:53  116.99
# 25                   salvador             BA  2018-04-10 15:51:53  116.99
# 26             rio de janeiro             RJ  2017-05-15 17:10:12  124.99
# 27                   linhares             ES  2017-04-06 02:15:36  126.99
# 28                 mandaguari             PR  2018-04-16 09:28:31  116.99
# 29                 mandaguari             PR  2018-04-16 09:28:31  116.99
# ...                       ...            ...                  ...     ...
# 118285                 franca             SP  2018-03-23 17:28:54   30.00
# 118286              sao paulo             SP  2018-04-25 08:30:06  159.00
# 118287               brasilia             DF  2018-03-15 18:15:37  135.13
# 118288           praia grande             SP  2018-02-15 16:07:57  119.90
# 118289        nazare paulista             SP  2018-02-06 17:59:15  240.00
# 118290        bento goncalves             RS  2017-09-29 09:35:15  399.99
# 118291  santa barbara d'oeste             SP  2018-04-24 06:30:57   39.90
# 118292              sao paulo             SP  2017-10-23 22:05:18   28.96
# 118293         ribeirao preto             SP  2018-03-13 02:48:54  394.90
# 118294     sao caetano do sul             SP  2018-06-26 14:32:11   26.90
# 118295     sao caetano do sul             SP  2018-06-26 14:32:11   26.90
# 118296     sao caetano do sul             SP  2018-06-26 14:32:11   26.90
# 118297               campinas             SP  2017-08-16 00:50:20   89.90
# 118298                  seara             SC  2017-05-17 18:15:22   94.90
# 118299            hortolandia             SP  2018-08-16 02:50:18   10.00
# 118300           santa teresa             ES  2018-03-29 23:30:23   57.00
# 118301                guaruja             SP  2017-06-19 12:35:04  312.90
# 118302              araguaina             TO  2018-01-31 12:31:27  526.00
# 118303                  mafra             SC  2018-02-14 18:32:21   16.90
# 118304                 osasco             SP  2018-02-14 07:35:56   37.00
# 118305                 osasco             SP  2018-02-14 07:35:56   37.00
# 118306               paicandu             PR  2017-08-08 03:03:55   59.90
# 118307                formosa             GO  2018-06-28 20:16:03  189.90
# 118308              sao paulo             SP  2017-03-24 18:33:07   39.90
# 118309              sao paulo             SP  2018-07-25 04:31:33   99.90
# 118310              sao paulo             SP  2017-04-02 23:23:38   19.99
# 118311    sao miguel do guama             PA  2017-12-13 23:50:32  250.00
# 118312              sao paulo             SP  2018-04-10 18:08:41   84.90
# 118313            bom repouso             MG  2017-11-24 12:15:25  167.99
# 118314            bom repouso             MG  2017-11-24 12:15:25  167.99
#
#         freight_value          product_category_name  product_weight_g  \
# 0               21.88              moveis_escritorio            8683.0
# 1               24.90              moveis_escritorio            8683.0
# 2               24.90              moveis_escritorio            8683.0
# 3               15.62              moveis_escritorio            8683.0
# 4               30.59              moveis_escritorio            8683.0
# 5               15.06              moveis_escritorio            8683.0
# 6               30.71              moveis_escritorio            8683.0
# 7               21.34              moveis_escritorio            8683.0
# 8               33.08              moveis_escritorio            8683.0
# 9               21.76              moveis_escritorio            8683.0
# 10              21.76              moveis_escritorio            8683.0
# 11              15.62              moveis_escritorio            8683.0
# 12              15.62              moveis_escritorio            8683.0
# 13              15.62              moveis_escritorio            8683.0
# 14              15.62              moveis_escritorio            8683.0
# 15              15.62              moveis_escritorio            8683.0
# 16              15.62              moveis_escritorio            8683.0
# 17              38.59              moveis_escritorio            8683.0
# 18              34.18              moveis_escritorio            8683.0
# 19              15.01              moveis_escritorio            8683.0
# 20              15.01              moveis_escritorio            8683.0
# 21              43.19              moveis_escritorio            8683.0
# 22              23.46              moveis_escritorio            8683.0
# 23              28.15              moveis_escritorio            8683.0
# 24              37.97              moveis_escritorio            8683.0
# 25              37.97              moveis_escritorio            8683.0
# 26              15.04              moveis_escritorio            8683.0
# 27              16.59              moveis_escritorio            8683.0
# 28              57.08              moveis_escritorio            8683.0
# 29              57.08              moveis_escritorio            8683.0
# ...               ...                            ...               ...
# 118285          12.79                     automotivo             500.0
# 118286          17.08                  esporte_lazer            1014.0
# 118287          18.83        sinalizacao_e_seguranca             425.0
# 118288          14.57                   beleza_saude            1350.0
# 118289          19.57               moveis_decoracao            3100.0
# 118290          84.66                     cool_stuff           18600.0
# 118291          15.23    fashion_bolsas_e_acessorios             150.0
# 118292           8.72             ferramentas_jardim             600.0
# 118293          14.89         informatica_acessorios             813.0
# 118294          15.29          utilidades_domesticas             445.0
# 118295          15.29          utilidades_domesticas             445.0
# 118296          15.29          utilidades_domesticas             445.0
# 118297          13.65                  esporte_lazer            1800.0
# 118298          19.90               malas_acessorios            1000.0
# 118299           8.29                     perfumaria             150.0
# 118300          18.28               eletrodomesticos             350.0
# 118301          14.15         informatica_acessorios            2400.0
# 118302          28.96             relogios_presentes             700.0
# 118303          15.10                cama_mesa_banho             300.0
# 118304          14.10  industria_comercio_e_negocios             400.0
# 118305          14.10  industria_comercio_e_negocios             400.0
# 118306          17.67                     automotivo           16700.0
# 118307          19.43                 consoles_games             200.0
# 118308          11.74               moveis_decoracao             800.0
# 118309          21.14                  casa_conforto            1500.0
# 118310          10.96                       pet_shop             300.0
# 118311          54.11                   beleza_saude            2400.0
# 118312           7.46    fashion_bolsas_e_acessorios             300.0
# 118313          31.93                    eletronicos            6185.0
# 118314          31.93                    eletronicos            6185.0
#
#         product_length_cm  product_height_cm  product_width_cm payment_type  \
# 0                    54.0               64.0              31.0  credit_card
# 1                    54.0               64.0              31.0  credit_card
# 2                    54.0               64.0              31.0  credit_card
# 3                    54.0               64.0              31.0  credit_card
# 4                    54.0               64.0              31.0  credit_card
# 5                    54.0               64.0              31.0  credit_card
# 6                    54.0               64.0              31.0       boleto
# 7                    54.0               64.0              31.0  credit_card
# 8                    54.0               64.0              31.0  credit_card
# 9                    54.0               64.0              31.0       boleto
# 10                   54.0               64.0              31.0       boleto
# 11                   54.0               64.0              31.0  credit_card
# 12                   54.0               64.0              31.0  credit_card
# 13                   54.0               64.0              31.0  credit_card
# 14                   54.0               64.0              31.0  credit_card
# 15                   54.0               64.0              31.0  credit_card
# 16                   54.0               64.0              31.0  credit_card
# 17                   54.0               64.0              31.0  credit_card
# 18                   54.0               64.0              31.0  credit_card
# 19                   54.0               64.0              31.0  credit_card
# 20                   54.0               64.0              31.0  credit_card
# 21                   54.0               64.0              31.0  credit_card
# 22                   54.0               64.0              31.0       boleto
# 23                   54.0               64.0              31.0  credit_card
# 24                   54.0               64.0              31.0  credit_card
# 25                   54.0               64.0              31.0      voucher
# 26                   54.0               64.0              31.0      voucher
# 27                   54.0               64.0              31.0       boleto
# 28                   54.0               64.0              31.0  credit_card
# 29                   54.0               64.0              31.0  credit_card
# ...                   ...                ...               ...          ...
# 118285               20.0               15.0              15.0  credit_card
# 118286               25.0               22.0              22.0  credit_card
# 118287               45.0               21.0              23.0  credit_card
# 118288               42.0               11.0              12.0  credit_card
# 118289               36.0               14.0              26.0       boleto
# 118290               38.0               74.0              38.0  credit_card
# 118291               16.0                9.0              11.0       boleto
# 118292               16.0               31.0              18.0  credit_card
# 118293               32.0               16.0              16.0       boleto
# 118294               23.0               12.0              14.0  credit_card
# 118295               23.0               12.0              14.0  credit_card
# 118296               23.0               12.0              14.0  credit_card
# 118297               55.0               10.0              14.0  credit_card
# 118298               16.0               46.0              36.0  credit_card
# 118299               23.0               14.0              16.0       boleto
# 118300               33.0                3.0              36.0  credit_card
# 118301               60.0               45.0              20.0  credit_card
# 118302               20.0               13.0              13.0  credit_card
# 118303               16.0               12.0              11.0  credit_card
# 118304               20.0               20.0              30.0       boleto
# 118305               20.0               20.0              30.0       boleto
# 118306               78.0                4.0              47.0       boleto
# 118307               20.0               11.0              16.0  credit_card
# 118308               25.0               25.0              25.0  credit_card
# 118309               45.0               30.0              45.0       boleto
# 118310               16.0               16.0              16.0  credit_card
# 118311               33.0               10.0              16.0  credit_card
# 118312               16.0               16.0              11.0  credit_card
# 118313               63.0               11.0              20.0  credit_card
# 118314               63.0               11.0              20.0  credit_card
#
#         payment_installments  review_score
# 0                          2             4
# 1                          1             1
# 2                          1             1
# 3                          7             3
# 4                         10             4
# 5                          5             4
# 6                          1             4
# 7                          2             2
# 8                          3             3
# 9                          1             2
# 10                         1             2
# 11                         6             4
# 12                         6             4
# 13                         6             4
# 14                         6             4
# 15                         6             4
# 16                         6             4
# 17                         1             2
# 18                         1             3
# 19                         5             3
# 20                         5             3
# 21                         1             4
# 22                         1             2
# 23                         1             5
# 24                         1             2
# 25                         1             2
# 26                         1             5
# 27                         1             5
# 28                        10             5
# 29                        10             5
# ...                      ...           ...
# 118285                     1             5
# 118286                     1             5
# 118287                     2             5
# 118288                     2             5
# 118289                     1             4
# 118290                     3             5
# 118291                     1             2
# 118292                     3             5
# 118293                     1             4
# 118294                     1             5
# 118295                     1             5
# 118296                     1             5
# 118297                     2             5
# 118298                    10             5
# 118299                     1             1
# 118300                     1             1
# 118301                    10             5
# 118302                     8             1
# 118303                     1             5
# 118304                     1             5
# 118305                     1             5
# 118306                     1             5
# 118307                    10             1
# 118308                     1             5
# 118309                     1             3
# 118310                     1             4
# 118311                     4             4
# 118312                     3             5
# 118313                     5             1
# 118314                     1             1
#
# [118315 rows x 13 columns]

# %%
# a = pd.to_datetime(costumers_dataset['shipping_limit_date'])
# A = datetime.timestamp(a[0])
# print(A)
costumers_dataset['shipping_limit_date'] = costumers_dataset['shipping_limit_date'].apply(lambda x: datetime.timestamp(pd.to_datetime(x)))
costumers_dataset['customer_city'] = costumers_dataset['customer_city'].astype('category')
costumers_dataset['customer_state'] = costumers_dataset['customer_state'].astype('category')
costumers_dataset['product_category_name'] = costumers_dataset['product_category_name'].astype('category')
costumers_dataset['payment_type'] = costumers_dataset['payment_type'].astype('category')

costumers_dataset['customer_city'] = costumers_dataset['customer_city'].cat.codes
costumers_dataset['customer_state'] = costumers_dataset['customer_state'].cat.codes
costumers_dataset['product_category_name'] = costumers_dataset['product_category_name'].cat.codes
costumers_dataset['payment_type'] = costumers_dataset['payment_type'].cat.codes

# %%
costumers_dataset = costumers_dataset.dropna()

# %%
from minisom import MiniSom    
som = MiniSom(6, 6, 13, sigma=0.5, learning_rate=0.5)
som.train_random(costumers_dataset.values, 100)
